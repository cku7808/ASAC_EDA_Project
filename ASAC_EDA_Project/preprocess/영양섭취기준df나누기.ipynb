# %%
import pandas as pd
import os

# %%
# # # 영양소 excel 파일별로 필요한 항목 추출 및 csv 저장 
# file_path = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/rawdata/전처리전"

# for file in os.listdir(file_path):
#   # name = file.split(".")[0]

#   p = os.path.join(file_path,file)
#   data = pd.read_excel(p)

# #   male = data.iloc[4:13,:].iloc[4:6,:]
# #   female = data.iloc[13:22].iloc[4:6,:]
# #   male.iloc[:,0] = "남자"
# #   female.iloc[:,0] = "여자"

# #   result = pd.concat([male,female])
# #   result.reset_index(drop=True, inplace=True)

# #   tmp = [name,name,name,name]
# #   result.insert(0,"영양소",tmp)

# #   result.to_csv(p,index=False)

# %%
# # 생성한 csv 파일들 하나의 df로 합치기 
# file_path = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/rawdata/전처리 후"

# main_data = pd.read_csv(os.path.join(file_path, os.listdir(file_path)[0]))
# for idx,file in enumerate(os.listdir(file_path)):
#   p = os.path.join(file_path,file)
#   if idx != 0:
#     curf = pd.read_csv(p)
#     main_data = pd.concat([main_data,curf])

# %%
# main_data.reset_index(drop=True, inplace=True)
# main_data
# Out:
#            영양소  성별     연령  필요 추정량  권장 섭취량  충분 섭취량   감소섭취량      섭취량  상한 섭취량  \
# 0      나트륨  남자  19-29     NaN     NaN  1500.0  2300.0      NaN     NaN
# 1      나트륨  남자  30-49     NaN     NaN  1500.0  2300.0      NaN     NaN
# 2      나트륨  여자  19-29     NaN     NaN  1500.0  2300.0      NaN     NaN
# 3      나트륨  여자  30-49     NaN     NaN  1500.0  2300.0      NaN     NaN
# 4          당  남자  19-29     NaN     NaN     NaN     NaN  260-520     NaN
# ..         ...  ..    ...     ...     ...     ...     ...      ...     ...
# 59  탄수화물  여자  30-49     NaN   130.0     NaN     NaN      NaN     NaN
# 60      칼슘  남자  19-29     NaN   800.0     NaN     NaN      NaN  2500.0
# 61      칼슘  남자  30-49     NaN   800.0     NaN     NaN      NaN  2500.0
# 62      칼슘  여자  19-29     NaN   700.0     NaN     NaN      NaN  2500.0
# 63      칼슘  여자  30-49     NaN   700.0     NaN     NaN      NaN  2500.0
#
#     평균 필요량 상한섭취량
# 0      NaN   NaN
# 1      NaN   NaN
# ...

# %%
# main_data.fillna(0, inplace=True)

# %%
# export_path = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/rawdata/전처리 후/nutrition_standard_final.csv"
# main_data.to_csv(export_path)

# %%
# export_path2 = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/nutrition_standard_final.xlsx"
# main_data.to_csv(export_path2)

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/final/nutrition_amount_for_female_20s.csv"

# %%
f_data = pd.read_csv(path)
f_data
# Out:
#                            영양소       평균   표준오차      p1      p5      p10  \
# 0                에너지 섭취량(kcal)  1634.49  42.66  346.98  708.10   874.63
# 1                   단백질 섭취량(g)    59.49   1.78   14.79   20.24    27.45
# 2                    지방 섭취량(g)    51.17   2.12    7.75   12.50    17.59
# 3                  탄수화물 섭취량(g)   218.76   5.53   42.98   84.98   104.98
# 4                     당 섭취량(g)    55.51   2.57    4.98    8.05    14.53
# 5                   칼슘 섭취량(mg)   439.14  16.56   64.29  116.95   171.32
# 6                    인 섭취량(mg)   855.21  24.04  212.20  327.66   423.28
# 7                    철 섭취량(mg)     8.66   0.34    1.81    2.87     3.52
# 8                  나트륨 섭취량(mg)  2546.30  75.05  317.66  745.72  1019.71
# 9                   칼륨 섭취량(mg)  2052.97  64.81  525.18  835.61   959.87
# 10  비타민A(레티놀 활성 당량) 섭취량(μgRAE)   367.07  29.68   23.02   72.05   103.64
# 11                 티아민 섭취량(mg)     1.03   0.04    0.25    0.34     0.42
# ...

# %%
tmp = ["에너지","단백질","지방","탄수화물","당","칼슘","인","철","나트륨","칼륨","비타민a","티아민","리보플라빈","니아신","비타민c","엽산"]

# %%
f_data["영양소"] = tmp

# %%
f_data.to_csv(path)

# %%
path = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/final/nutrition_amount_for_male_20s.csv"
m_data = pd.read_csv(path)
m_data["영양소"] = tmp
m_data.to_csv(path)
