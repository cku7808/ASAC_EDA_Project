# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/final/식품db.xlsx"

# %%
data = pd.read_excel(path,sheet_name="시트1")
data
# Out:
#          식품명      철           칼륨         에너지          칼슘    비타민a     엽산  \
# 0    삼계탕/닭곰탕   3.86  1406.480000  911.390000  123.290000   76.13  60.96
# 1         후추  12.97  1366.000000  362.000000  391.000000   31.00  15.00
# 2       스파게티   3.05  1094.450000  642.580000  214.540000   23.44  72.00
# 3       감자튀김   1.55   985.330000  467.750000   19.540000    0.00  29.21
# 4     닭튀김/강정   2.18   947.200000  903.000000   39.800000   29.15  49.23
# ..       ...    ...          ...         ...         ...     ...    ...
# 120       젤리   0.18     8.000000  344.000000    6.000000    0.00   1.00
# 121     탄산음료   0.04     4.545455   36.090909    2.909091    0.00   0.00
# 122      김구이   4.50     0.000000   19.000000  490.000000  336.00   0.00
# 123      골뱅이   2.60     0.000000   76.000000   46.000000    0.00   0.00
# 124       소주   0.00     0.000000  127.000000    0.000000    0.00   0.00
#
#           비타민c    단백질        지방    탄수화물       당           인          나트륨  \
# ...

# %%
path = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/data_20s_unique.csv"

# %%
data = pd.read_csv(path)
data.drop(columns = "Unnamed: 0",inplace=True)

# %%
data
# Out:
#     순위_x  19-29 음식  19-29 비율(%)_x  19-29 표준오차(%)_x  이상값_x  순위_y  \
# 0   35.0       닭고기           5.22             1.59  False   NaN
# 1   39.0       짜장면           4.63             1.48  False   NaN
# 2   49.0        분유           4.17             1.33  False   NaN
# 3   50.0        춘장           4.02             1.74  False   NaN
# 4   55.0       탕수육           3.83             1.30  False   NaN
# 5   59.0      마요네즈           3.59             1.30  False   NaN
# 6   63.0  갈비구이, 돼지           3.20             1.33  False   NaN
# 7   65.0       순대국           3.18             1.19  False   NaN
# 8   66.0      모밀국수           3.13             1.40  False   NaN
# 9   67.0       햄구이           3.11             1.25  False   NaN
# 10  68.0       복숭아           3.06             1.26  False   NaN
# 11  71.0        족발           2.92             1.08  False   NaN
# 12  75.0    돼지고기구이           2.73             0.87  False   NaN
# 13  79.0       파김치           2.54             1.14  False   NaN
# ...

# %%
m_unique = data.iloc[:18,:]
f_unique = data.iloc[18:,:]

# %%
f_unique.drop(columns=["순위_x","19-29 비율(%)_x","19-29 표준오차(%)_x","이상값_x","남자-여자 순위 차이","abs(남자-여자 순위 차이)"],inplace=True)
# Out:
# <ipython-input-23-401bb772a67e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_unique.drop(columns=["순위_x","19-29 비율(%)_x","19-29 표준오차(%)_x","이상값_x","남자-여자 순위 차이","abs(남자-여자 순위 차이)"],inplace=True)

# %%
m_unique.drop(columns=["순위_y","19-29 비율(%)_y","19-29 표준오차(%)_y","이상값_y","남자-여자 순위 차이","abs(남자-여자 순위 차이)"],inplace=True)
# Out:
# <ipython-input-24-b059cb30b250>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_unique.drop(columns=["순위_y","19-29 비율(%)_y","19-29 표준오차(%)_y","이상값_y","남자-여자 순위 차이","abs(남자-여자 순위 차이)"],inplace=True)

# %%
m_unique
# Out:
#     순위_x  19-29 음식  19-29 비율(%)_x  19-29 표준오차(%)_x  이상값_x
# 0   35.0       닭고기           5.22             1.59  False
# 1   39.0       짜장면           4.63             1.48  False
# 2   49.0        분유           4.17             1.33  False
# 3   50.0        춘장           4.02             1.74  False
# 4   55.0       탕수육           3.83             1.30  False
# 5   59.0      마요네즈           3.59             1.30  False
# 6   63.0  갈비구이, 돼지           3.20             1.33  False
# 7   65.0       순대국           3.18             1.19  False
# 8   66.0      모밀국수           3.13             1.40  False
# 9   67.0       햄구이           3.11             1.25  False
# 10  68.0       복숭아           3.06             1.26  False
# 11  71.0        족발           2.92             1.08  False
# 12  75.0    돼지고기구이           2.73             0.87  False
# 13  79.0       파김치           2.54             1.14  False
# 14  80.0       완자전           2.51             1.03  False
# ...

# %%
f_unique
# Out:
#    19-29 음식  순위_y  19-29 비율(%)_y  19-29 표준오차(%)_y  이상값_y
# 18       홍차  48.0           4.34             1.46  False
# 19      도우넛  57.0           3.50             1.38  False
# 20  오렌지, 주스  59.0           3.43             0.92  False
# 21    페이스트리  61.0           3.33             1.36  False
# 22       포도  63.0           3.13             1.34  False
# 23       어묵  66.0           2.93             1.30  False
# 24     총각김치  67.0           2.92             1.00  False
# 25   오징어채볶음  71.0           2.81             1.13  False
# 26        쨈  72.0           2.81             1.17  False
# 27    청국장찌개  74.0           2.73             1.23  False
# 28      현미밥  75.0           2.73             0.94  False
# 29      핫소스  76.0           2.68             1.29  False
# 30       초밥  77.0           2.62             1.09  False
# 31       짬뽕  78.0           2.61             1.20  False
# 32      어묵국  79.0           2.61             0.98  False
# ...

# %%
inf = float("inf")
tmp = f_unique.iloc[:,0].to_frame()
tmp["남성 순위"] = [0]*len(f_unique)
tmp["여성 순위"] = f_unique.iloc[:,1]
tmp["남자-여자 순위 차이"] = [100]*len(f_unique)
tmp["abs(남자-여자 순위 차이)"] = [100]*len(f_unique)
tmp["선호 성별"] = ["여"]*len(f_unique)

# %%
inf = float("inf")
tmp1 = f_unique.iloc[:,0].to_frame()
tmp1["남성 순위"] = m_unique.iloc[:,1]
tmp1["여성 순위"] = [0]*len(f_unique)
tmp1["남자-여자 순위 차이"] = [100]*len(f_unique)
tmp1["abs(남자-여자 순위 차이)"] = [100]*len(f_unique)
tmp1["선호 성별"] = ["남"]*len(f_unique)

# %%
tmp.rename(columns={"19-29 음식":"음식"},inplace=True)
tmp1.rename(columns={"19-29 음식":"음식"},inplace=True)

# %%
f_unique = tmp
m_unique = tmp1

# %%
f_prefer_path = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/final/female20_prefer.csv"
m_prefer_path = "/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/final/male20_prefer.csv"

# %%
f_prefer = pd.read_csv(f_prefer_path)
m_prefer = pd.read_csv(m_prefer_path)

# %%
f_prefer.drop(columns="Unnamed: 0",inplace=True)
m_prefer.drop(columns="Unnamed: 0",inplace=True)

# %%
f_result = pd.concat([f_unique,f_prefer])
f_result.reset_index(drop=True,inplace=True)

# %%
m_result = pd.concat([m_unique,m_prefer])
m_result.reset_index(drop=True,inplace=True)

# %%
m_result.to_csv("/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/final/m20_final.csv")
f_result.to_csv("/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/final/f20_final.csv")

# %%
# m_unique.to_csv("/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/final/m20_unique.csv")
# f_unique.to_csv("/content/drive/MyDrive/Tacademy ASAC/EDA Project/finishedData/final/f20_unique.csv")
